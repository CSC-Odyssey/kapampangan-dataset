# %%
import pandas as pd

df = pd.read_csv('../csv/ScrapeSongs.csv')
df
# Out:
#                             lyrics
# 0                                “
# 1              Indung alang musing
# 2                               ”
# 3             Indung alang musing
# 4                King kekang awus
# ..                             ...
# 210  Virgen virgen delos remedios
# 211           Indu na ning dios a
# 212                    mapaglunus
# 213  Virgen virgen delos remedios
# 214       Patune ka tugut, mamaus
#
# [215 rows x 1 columns]

# %%
import gensim

def sent_to_words(contents):
    for sentence in contents:
        yield(gensim.utils.simple_preprocess(sentence, deacc=True))  # deacc=True removes punctuations


words = list(sent_to_words(df['lyrics'].values.tolist()))
words
# Out:
# [[],
#  ['indung', 'alang', 'musing'],
#  [],
#  ['indung', 'alang', 'musing'],
#  ['king', 'kekang', 'awus'],
#  ['arap', 'ning', 'altar', 'mu'],
#  ['nio', 'ke', 'dudurup'],
#  ['ave', 'ave', 'ave', 'maria'],
#  ['ave', 'ave', 'ave', 'maria'],
#  ['panalangin', 'mi', 'ya'],
#  ['bansa', 'ming', 'beitan'],
#  ['at', 'ding', 'sablang', 'bansa'],
#  ['diyan', 'mong', 'kapayapan'],
#  ['ave', 'ave', 'ave', 'maria'],
#  ['ave', 'ave', 'ave', 'maria'],
#  ['birhen', 'ning', 'fatima'],
#  [],
#  ['birhen', 'ning', 'fatima'],
#  ['ni', 'ke', 'makasiklawud'],
#  ['ban', 'adwan', 'kekang', 'kasaupan'],
#  ['payapa', 'sa', 'ing', 'labuad'],
#  ['indu', 'ituru', 'mu', 'kami'],
#  ['ing', 'dalan', 'ming', 'tukyan'],
#  ['keka', 'babie', 'ning', 'lugud', 'mi'],
#  ['at', 'rosario', 'keka', 'yampang'],
#  ['pengaku', 'mu', 'fatima'],
#  ['baling', 'patalip', 'ka'],
#  ['ing', 'saupan', 'mu', 'keng', 'parati'],
#  ['nung', 'mangadi', 'kami'],
#  ['indu', 'king', 'balang', 'aldo'],
#  ['tayran', 'mu', 'ke', 'sana'],
#  ['ban', 'payapa', 'ya', 'ing', 'yatu'],
#  ['at', 'pantualu', 'mu', 'keng', 'sabla'],
#  ['indu', 'dalangin', 'mu', 'ya'],
#  [],
#  ['indu', 'dalangin', 'mu', 'ya'],
#  ['ing', 'lulutang', 'king', 'dusa'],
#  ['pablasang', 'ining', 'kabyayan', 'na'],
#  ['mibusal', 'kening', 'sigwa'],
#  ['indung', 'birhen', 'maria'],
#  ['mipnu', 'ka', 'king', 'gracia'],
#  ['aku', 'pung', 'magsakdal', 'keka'],
#  ['ampunan', 'mu', 'ku', 'sana'],
#  ['indung', 'mal', 'damdaman', 'mu'],
#  ['manigapung', 'aklis', 'ku'],
#  ['sawpan', 'mu', 'ku', 'sawpan', 'mu', 'ku'],
#  ['angga', 'pu', 'keng', 'babo'],
#  ['indung', 'virgen'],
#  ['indung', 'birhen', 'mamung', 'santungan'],
#  ['ku'],
#  ['damdam', 'ka', 'sana', 'king', 'aklis', 'ku'],
#  ['indu', 'sabyan', 'mu', 'ing', 'daptan', 'ku'],
#  ['ref', 'lupa', 'mu', 'cang', 'hesus', 'makawili'],
#  ['lalam', 'ning', 'mantu', 'mung', 'tahimik'],
#  ['takde', 'mu', 'kang', 'hesus', 'makakawul'],
#  ['indu', 'mantabe', 'ka', 'kaku'],
#  ['kekang', 'reyna', 'mu', 'ke', 'pabustan'],
#  ['saupan', 'mu', 'kami', 'king', 'labanan'],
#  ['at', 'kaibat', 'mi', 'keting', 'kakarinan'],
#  ['king', 'banwa', 'ke', 'ngan', 'tupunan'],
#  ['ref', 'lupa', 'mu', 'kang', 'hesus'],
#  [],
#  ['ave', 'de', 'fatima'],
#  ['niang', 'rece', 'ya', 'ing', 'mayo'],
#  ['ing', 'birhen', 'maria'],
#  ['tinipa', 'ya', 'karin'],
#  ['king', 'cova', 'de', 'iria'],
#  ['ave', 'ave', 'ave', 'maria'],
#  ['aku', 'ing', 'senora'],
#  ['ning', 'santo', 'rosaryo'],
#  ['ngana', 'karing', 'anak'],
#  ['keka', 'dinalo'],
#  ['ave', 'ave'],
#  [],
#  ['ing', 'mais', 'ku', 'imbut'],
#  [],
#  ['ngana', 'pin', 'karala'],
#  ['ing', 'santo', 'rosaryo'],
#  ['pangadian', 'ye', 'sana'],
#  ['ave', 'ave'],
#  [],
#  ['ding', 'makasalanan'],
#  ['tutu', 'nong', 'merangal'],
#  ['pangadi', 'yo', 'sana'],
#  ['balang', 'mangumpisal'],
#  ['ave', 'ave'],
#  [],
#  ['ngeni', 'atyu', 'keto'],
#  ['ban', 'ipatupad', 'na'],
#  ['ing', 'bilin', 'na', 'karin'],
#  ['king', 'cova', 'de', 'iria'],
#  ['ave', 'ave'],
#  [],
#  ['eta', 'sasalanan'],
#  ['ing', 'pamagrosario'],
#  ['king', 'pamilya', 'tamu'],
#  ['kilub', 'ning', 'aldo', 'aldo'],
#  ['ave', 'ave'],
#  [],
#  ['dalit', 'bayu', 'ya', 'ilako', 'ing', 'laruan'],
#  ['miras', 'na', 'ing', 'paglako', 'mu', 'keti'],
#  ['keting', 'malukang', 'karinan', 'mi'],
#  ['indung', 'malugud', 'kekami'],
#  ['antabayanan', 'mu', 'ke', 'sang', 'parati'],
#  ['kasampat', 'na', 'kaligaya'],
#  [],
#  ['ning', 'bie', 'magrosarying', 'mipapamilya'],
#  ['ing', 'guinung', 'diyos', 'kekang', 'grasya'],
#  ['karin', 'alang', 'lipat', 'babie', 'nay'],
#  ['magrosaryo', 'ke', 'aldo', 'aldo'],
#  ['indu', 'na', 'ning', 'pakalulu'],
#  ['ban', 'ing', 'pamikalugud', 'tamu'],
#  ['masese', 'ban', 'payapa', 'ya', 'ing', 'yatu'],
#  ['ref', 'kasampat'],
#  ['na'],
#  [],
#  ['virgen', 'de', 'los', 'remedios'],
#  ['official', 'hymn'],
#  [],
#  ['indu', 'ming', 'virgen', 'kekeng'],
#  ['patulunan'],
#  ['ikang', 'minie', 'tula', 'ampong'],
#  ['kapayapan'],
#  ['king', 'indu', 'ming', 'balen', 'kekeng'],
#  ['lalawigan'],
#  ['uling', 'kalimbun', 'mu', 'kareng'],
#  ['sablangdalan'],
#  ['ding', 'barios', 'at', 'purok', 'kareng'],
#  ['kabalenan'],
#  ['agad', 'menatili', 'king', 'katahimikan'],
#  ['ii'],
#  ['ding', 'sablang', 'pisamban', 'ampon'],
#  ['ding', 'bisitas'],
#  ['kekang', 'delawan', 'virgen'],
#  ['maslag'],
#  ['ding', 'anggang', 'memalen', 'pigdala'],
#  ['mung', 'lamak'],
#  ['metula', 'lang', 'dakal', 'keka', 'pasalamat'],
#  ['kasalpantayanan', 'miunlad'],
#  ['milablab'],
#  ['ing', 'pamikalugud', 'agad', 'linaganap'],
#  ['koro'],
#  ['virgen', 'delos', 'remedios'],
#  ['damdam', 'ka', 'kingkekeng', 'aus'],
#  ['iligtas', 'mu', 'ke', 'ikabus'],
#  ['king', 'sablang', 'tuksu', 'at', 'marok'],
#  ['ibie', 'mu', 'ing', 'kekang', 'lunus'],
#  ['panalangin', 'mu', 'ke', 'king', 'dios'],
#  ['sulu'],
#  ['sulu', 'na', 'ka', 'ning', 'meto', 'lelangan'],
#  ['ika', 'ing', 'bulaclac', 'sari', 'king'],
#  ['leguan'],
#  ['anie', 'pin', 'mo', 'meto', 'ketawan'],
#  ['dururup', 'king', 'kekang'],
#  ['kabanalan'],
#  ['coro'],
#  ['indu', 'ning', 'dios', 'malunus', 'ca'],
#  ['sa'],
#  ['carening', 'alipan', 'mu'],
#  ['patawad', 'co', 'pu', 'kecami', 'indu'],
#  ['virgen', 'ning', 'pakalulu'],
#  ['pamun'],
#  ['kantang', 'pamamaalam'],
#  ['sa', 'virgen', 'delos', 'remedios', 'at', 'sto', 'cristo', 'del'],
#  ['pardon'],
#  ['mamun', 'na', 'ke', 'ngeni', 'indung'],
#  ['malugud'],
#  ['at', 'keka', 'jesus', 'ko', 'king', 'sala'],
#  ['menatbus', 'at'],
#  ['bayu', 'ke', 'sana', 'kekayu', 'gumulut'],
#  ['bendisyunan', 'yu', 'ke', 'sa', 'king'],
#  ['kalam', 'yu', 'lugud'],
#  [],
#  ['at', 'kabang', 'ati', 'ke', 'king', 'dalan'],
#  ['lalakad'],
#  ['ilisya', 'yu', 'ke', 'sa', 'king', 'marok'],
#  ['gasgas'],
#  ['mata', 'ming', 'malabug', 'pasalan'],
#  ['yong', 'ganap'],
#  ['karetang', 'bale', 'mi', 'malagwa', 'ke'],
#  ['miras'],
#  ['mamun', 'na', 'ke', 'ngeni', 'indung'],
#  ['malugud'],
#  ['karetang', 'bale', 'mi', 'ba', 'nang'],
#  ['payinturu'],
#  ['dinan', 'yu', 'ke', 'sana', 'king', 'mal'],
#  ['grasya', 'yu'],
#  ['anti', 'mong', 'pabakal', 'kekaming'],
#  ['anak', 'yu'],
#  ['virgen', 'delos', 'remedios'],
#  ['pampanga'],
#  [],
#  ['virgen', 'virgen', 'delos', 'remedios'],
#  ['indu', 'na', 'ning', 'dios'],
#  ['mapaglunus'],
#  ['virgen', 'virgen', 'delos', 'remedios'],
#  ['patune', 'ka', 'tugut', 'mamaus'],
#  ['ing', 'aus', 'ning', 'ginu', 'bulung', 'ning'],
#  ['indu'],
#  ['makiramdam', 'miadwanan'],
#  ['papunta', 'king', 'kayapan'],
#  ['virgen', 'virgen', 'delos', 'remedios'],
#  ['indu', 'na', 'ning', 'dios'],
#  ['mapaglunus'],
#  ['virgen', 'virgen', 'delos', 'remedios'],
#  ['patune', 'ka', 'tugut', 'mamaus'],
#  ['ing', 'lugud', 'ning', 'ginu', 'ing', 'lingap'],
#  ['ning', 'indu'],
#  ['pakamalan', 'palabungan'],
#  ['pagmasusian', 'ing', 'kapiestan'],
#  ['virgen', 'virgen', 'delos', 'remedios'],
#  ['indu', 'na', 'ning', 'dios'],
#  ['mapaglunus'],
#  ['virgen', 'virgen', 'delos', 'remedios'],
#  ['patune', 'ka', 'tugut', 'mamaus']]

# %%
import json

lst = [element for innerList in words for element in innerList]

with open('../json/NovelContent.json', 'w') as f:
    json.dump(lst, f)

# %%
words_df = pd.DataFrame(lst, columns=["words"])
words_df.to_csv("../csv/SongsContent.csv")

words_df
# Out:
#         words
# 0      indung
# 1       alang
# 2      musing
# 3      indung
# 4       alang
# ..        ...
# 678  remedios
# 679    patune
# 680        ka
# 681     tugut
# 682    mamaus
#
# [683 rows x 1 columns]
